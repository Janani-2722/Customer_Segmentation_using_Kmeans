# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, normalize
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\xnovaq.16\\Documents\\myenv\\Marketing_Project\\customer_segmentation_using_kmeans\\Marketing_analysis'

# %%
os.chdir("C:\\Users\\xnovaq.16\\Documents\\myenv\\Marketing_Project\\customer_segmentation_using_kmeans\\Marketing_analysis")

# %%
pwd
# Out:
# 'C:\\Users\\xnovaq.16\\Documents\\myenv\\Marketing_Project\\customer_segmentation_using_kmeans\\Marketing_analysis'

# %%
df = pd.read_csv(r"Marketing_data.csv")
df.head(10)
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
# 5  C10006  1809.828751           1.000000    1333.28              0.00
# 6  C10007   627.260806           1.000000    7091.01           6402.63
# 7  C10008  1823.652743           1.000000     436.20              0.00
# 8  C10009  1014.926473           1.000000     861.49            661.49
# 9  C10010   152.225975           0.545455    1281.60           1281.60
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                   95.40      0.000000             0.166667
# 1                    0.00   6442.945483             0.000000
# 2                    0.00      0.000000             1.000000
# 3                    0.00    205.788017             0.083333
# 4                    0.00      0.000000             0.083333
# 5                 1333.28      0.000000             0.666667
# 6                  688.38      0.000000             1.000000
# 7                  436.20      0.000000             1.000000
# 8                  200.00      0.000000             0.333333
# 9                    0.00      0.000000             0.166667
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
# 5                    0.000000                          0.583333
# 6                    1.000000                          1.000000
# 7                    0.000000                          1.000000
# 8                    0.083333                          0.250000
# 9                    0.166667                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
# 5                0.000000                 0              8        1800.0
# 6                0.000000                 0             64       13500.0
# 7                0.000000                 0             12        2300.0
# 8                0.000000                 0              5        7000.0
# 9                0.000000                 0              3       11000.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12
# 2   622.066742        627.284787          0.000000      12
# 3     0.000000               NaN          0.000000      12
# 4   678.334763        244.791237          0.000000      12
# 5  1400.057770       2407.246035          0.000000      12
# 6  6354.314328        198.065894          1.000000      12
# 7   679.065082        532.033990          0.000000      12
# 8   688.278568        311.963409          0.000000      12
# 9  1164.770591        100.302262          0.000000      12

# %%
df.shape
# Out:
# (8950, 18)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   str
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
#  11  CASH_ADVANCE_TRX                  8950 non-null   int64
#  12  PURCHASES_TRX                     8950 non-null   int64
#  13  CREDIT_LIMIT                      8949 non-null   float64
#  14  PAYMENTS                          8950 non-null   float64
#  15  MINIMUM_PAYMENTS                  8637 non-null   float64
#  16  PRC_FULL_PAYMENT                  8950 non-null   float64
#  17  TENURE                            8950 non-null   int64
# dtypes: float64(14), int64(3), str(1)
# memory usage: 1.2 MB

# %%
df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# 25%                  0.000000      0.000000             0.083333
# 50%                 89.000000      0.000000             0.500000
# 75%                468.637500   1113.821139             0.916667
# max              22500.000000  47137.211760             1.000000
#
#        ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# count                 8950.000000                       8950.000000
# mean                     0.202458                          0.364437
# std                      0.298336                          0.397448
# min                      0.000000                          0.000000
# 25%                      0.000000                          0.000000
# 50%                      0.083333                          0.166667
# 75%                      0.300000                          0.750000
# max                      1.000000                          1.000000
#
#        CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# count             8950.000000       8950.000000    8950.000000   8949.000000
# mean                 0.135144          3.248827      14.709832   4494.449450
# std                  0.200121          6.824647      24.857649   3638.815725
# min                  0.000000          0.000000       0.000000     50.000000
# 25%                  0.000000          0.000000       1.000000   1600.000000
# 50%                  0.000000          0.000000       7.000000   3000.000000
# 75%                  0.222222          4.000000      17.000000   6500.000000
# max                  1.500000        123.000000     358.000000  30000.000000
#
#            PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT       TENURE
# count   8950.000000       8637.000000       8950.000000  8950.000000
# mean    1733.143852        864.206542          0.153715    11.517318
# std     2895.063757       2372.446607          0.292499     1.338331
# min        0.000000          0.019163          0.000000     6.000000
# 25%      383.276166        169.123707          0.000000    12.000000
# 50%      856.901546        312.343947          0.000000    12.000000
# 75%     1901.134317        825.485459          0.142857    12.000000
# max    50721.483360      76406.207520          1.000000    12.000000

# %%
sns.boxplot(data = df)
plt.show()

# %%
skewed_cols = [
    'BALANCE', 'PURCHASES', 'ONEOFF_PURCHASES', 
    'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE',
    'CREDIT_LIMIT', 'PAYMENTS', 'MINIMUM_PAYMENTS'
]
for col in skewed_cols:
    df[col + '_LOG'] = np.log1p(df[col])

df_original = df[skewed_cols].copy()
df = df.drop(columns=skewed_cols)

df.head()
# Out:
#   CUST_ID  BALANCE_FREQUENCY  PURCHASES_FREQUENCY  ONEOFF_PURCHASES_FREQUENCY  \
# 0  C10001           0.818182             0.166667                    0.000000
# 1  C10002           0.909091             0.000000                    0.000000
# 2  C10003           1.000000             1.000000                    1.000000
# 3  C10004           0.636364             0.083333                    0.083333
# 4  C10005           1.000000             0.083333                    0.083333
#
#    PURCHASES_INSTALLMENTS_FREQUENCY  CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  \
# 0                          0.083333                0.000000                 0
# 1                          0.000000                0.250000                 4
# 2                          0.000000                0.000000                 0
# 3                          0.000000                0.083333                 1
# 4                          0.000000                0.000000                 0
#
#    PURCHASES_TRX  PRC_FULL_PAYMENT  TENURE  BALANCE_LOG  PURCHASES_LOG  \
# 0              2          0.000000      12     3.735304       4.568506
# 1              0          0.222222      12     8.071989       0.000000
# 2             12          0.000000      12     7.822504       6.651791
# 3              1          0.000000      12     7.419183       7.313220
# 4              1          0.000000      12     6.707735       2.833213
#
#    ONEOFF_PURCHASES_LOG  INSTALLMENTS_PURCHASES_LOG  CASH_ADVANCE_LOG  \
# 0              0.000000                    4.568506          0.000000
# 1              0.000000                    0.000000          8.770896
# 2              6.651791                    0.000000          0.000000
# 3              7.313220                    0.000000          5.331694
# 4              2.833213                    0.000000          0.000000
#
#    CREDIT_LIMIT_LOG  PAYMENTS_LOG  MINIMUM_PAYMENTS_LOG
# 0          6.908755      5.312231              4.945277
# 1          8.853808      8.319725              6.978531
# 2          8.922792      6.434654              6.442994
# 3          8.922792      0.000000                   NaN
# 4          7.090910      6.521114              5.504483

# %%
fig, axes = plt.subplots(len(skewed_cols), 2, figsize=(14, 60))

for i, col in enumerate(skewed_cols):
    # Before
    sns.histplot(df_original[col], ax=axes[i, 0], kde=True, color='red')
    axes[i, 0].set_title(f'{col} - Before Log Transform')
    
    # After
    sns.histplot(df[col + '_LOG'], ax=axes[i, 1], kde=True, color='green')
    axes[i, 1].set_title(f'{col}_LOG - After Log Transform')

plt.tight_layout()
plt.show()

# %%
df.head()
# Out:
#   CUST_ID  BALANCE_FREQUENCY  PURCHASES_FREQUENCY  ONEOFF_PURCHASES_FREQUENCY  \
# 0  C10001           0.818182             0.166667                    0.000000
# 1  C10002           0.909091             0.000000                    0.000000
# 2  C10003           1.000000             1.000000                    1.000000
# 3  C10004           0.636364             0.083333                    0.083333
# 4  C10005           1.000000             0.083333                    0.083333
#
#    PURCHASES_INSTALLMENTS_FREQUENCY  CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  \
# 0                          0.083333                0.000000                 0
# 1                          0.000000                0.250000                 4
# 2                          0.000000                0.000000                 0
# 3                          0.000000                0.083333                 1
# 4                          0.000000                0.000000                 0
#
#    PURCHASES_TRX  PRC_FULL_PAYMENT  TENURE  BALANCE_LOG  PURCHASES_LOG  \
# 0              2          0.000000      12     3.735304       4.568506
# 1              0          0.222222      12     8.071989       0.000000
# 2             12          0.000000      12     7.822504       6.651791
# 3              1          0.000000      12     7.419183       7.313220
# 4              1          0.000000      12     6.707735       2.833213
#
#    ONEOFF_PURCHASES_LOG  INSTALLMENTS_PURCHASES_LOG  CASH_ADVANCE_LOG  \
# 0              0.000000                    4.568506          0.000000
# 1              0.000000                    0.000000          8.770896
# 2              6.651791                    0.000000          0.000000
# 3              7.313220                    0.000000          5.331694
# 4              2.833213                    0.000000          0.000000
#
#    CREDIT_LIMIT_LOG  PAYMENTS_LOG  MINIMUM_PAYMENTS_LOG
# 0          6.908755      5.312231              4.945277
# 1          8.853808      8.319725              6.978531
# 2          8.922792      6.434654              6.442994
# 3          8.922792      0.000000                   NaN
# 4          7.090910      6.521114              5.504483

# %%
df.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE_FREQUENCY                     0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# BALANCE_LOG                           0
# PURCHASES_LOG                         0
# ONEOFF_PURCHASES_LOG                  0
# INSTALLMENTS_PURCHASES_LOG            0
# CASH_ADVANCE_LOG                      0
# CREDIT_LIMIT_LOG                      1
# PAYMENTS_LOG                          0
# MINIMUM_PAYMENTS_LOG                313
# dtype: int64

# %%
# Check who made one off purchase of approx.  $40761
df[(df.ONEOFF_PURCHASES_LOG == np.log1p(40761.250000))]
# Out:
#     CUST_ID  BALANCE_FREQUENCY  PURCHASES_FREQUENCY  \
# 550  C10574                1.0                  1.0
#
#      ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 550                         1.0                          0.916667
#
#      CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  \
# 550                0.083333                 1            101
#
#      PRC_FULL_PAYMENT  TENURE  BALANCE_LOG  PURCHASES_LOG  \
# 550              0.25      12     9.354313      10.800403
#
#      ONEOFF_PURCHASES_LOG  INSTALLMENTS_PURCHASES_LOG  CASH_ADVANCE_LOG  \
# 550             10.615512                    9.021516          6.326448
#
#      CREDIT_LIMIT_LOG  PAYMENTS_LOG  MINIMUM_PAYMENTS_LOG
# 550         10.021315     10.756446              7.998023

# %%
# Who made cash advance of $47000 and $48000
df[(df.CASH_ADVANCE_LOG >= np.log1p(47000)) & (df.CASH_ADVANCE_LOG <= np.log1p(48000))]
# Out:
#      CUST_ID  BALANCE_FREQUENCY  PURCHASES_FREQUENCY  \
# 2159  C12226                1.0             0.583333
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 2159                        0.25                               0.5
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  \
# 2159                     1.0               123             21
#
#       PRC_FULL_PAYMENT  TENURE  BALANCE_LOG  PURCHASES_LOG  \
# 2159               0.0      12     9.297073       6.070576
#
#       ONEOFF_PURCHASES_LOG  INSTALLMENTS_PURCHASES_LOG  CASH_ADVANCE_LOG  \
# 2159              4.901564                    5.701881         10.760839
#
#       CREDIT_LIMIT_LOG  PAYMENTS_LOG  MINIMUM_PAYMENTS_LOG
# 2159          9.883336     10.572588               8.59326

# %%
# Check for Null Values 
df.isna().sum()
# Out:
# CUST_ID                               0
# BALANCE_FREQUENCY                     0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# BALANCE_LOG                           0
# PURCHASES_LOG                         0
# ONEOFF_PURCHASES_LOG                  0
# INSTALLMENTS_PURCHASES_LOG            0
# CASH_ADVANCE_LOG                      0
# CREDIT_LIMIT_LOG                      1
# PAYMENTS_LOG                          0
# MINIMUM_PAYMENTS_LOG                313
# dtype: int64

# %%
df.head()
# Out:
#   CUST_ID  BALANCE_FREQUENCY  PURCHASES_FREQUENCY  ONEOFF_PURCHASES_FREQUENCY  \
# 0  C10001           0.818182             0.166667                    0.000000
# 1  C10002           0.909091             0.000000                    0.000000
# 2  C10003           1.000000             1.000000                    1.000000
# 3  C10004           0.636364             0.083333                    0.083333
# 4  C10005           1.000000             0.083333                    0.083333
#
#    PURCHASES_INSTALLMENTS_FREQUENCY  CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  \
# 0                          0.083333                0.000000                 0
# 1                          0.000000                0.250000                 4
# 2                          0.000000                0.000000                 0
# 3                          0.000000                0.083333                 1
# 4                          0.000000                0.000000                 0
#
#    PURCHASES_TRX  PRC_FULL_PAYMENT  TENURE  BALANCE_LOG  PURCHASES_LOG  \
# 0              2          0.000000      12     3.735304       4.568506
# 1              0          0.222222      12     8.071989       0.000000
# 2             12          0.000000      12     7.822504       6.651791
# 3              1          0.000000      12     7.419183       7.313220
# 4              1          0.000000      12     6.707735       2.833213
#
#    ONEOFF_PURCHASES_LOG  INSTALLMENTS_PURCHASES_LOG  CASH_ADVANCE_LOG  \
# 0              0.000000                    4.568506          0.000000
# 1              0.000000                    0.000000          8.770896
# 2              6.651791                    0.000000          0.000000
# 3              7.313220                    0.000000          5.331694
# 4              2.833213                    0.000000          0.000000
#
#    CREDIT_LIMIT_LOG  PAYMENTS_LOG  MINIMUM_PAYMENTS_LOG
# 0          6.908755      5.312231              4.945277
# 1          8.853808      8.319725              6.978531
# 2          8.922792      6.434654              6.442994
# 3          8.922792      0.000000                   NaN
# 4          7.090910      6.521114              5.504483

# %%
df['MINIMUM_PAYMENTS_LOG'].mean()
# Out:
# np.float64(5.922195186353701)

# %%
# Fill up the missing elements with mean of the 'MINIMUM_PAYMENT’ 
df['MINIMUM_PAYMENTS_LOG'] = df['MINIMUM_PAYMENTS_LOG'].fillna(df['MINIMUM_PAYMENTS_LOG'].mean(), inplace = True)
df['MINIMUM_PAYMENTS_LOG']
# Out:
# 0       4.945277
# 1       6.978531
# 2       6.442994
# 3       5.922195
# 4       5.504483
#           ...
# 8945    3.909748
# 8946    5.922195
# 8947    4.423869
# 8948    4.038755
# 8949    4.491878
# Name: MINIMUM_PAYMENTS_LOG, Length: 8950, dtype: float64

# %%
df['CREDIT_LIMIT_LOG'].mean()
# Out:
# np.float64(8.094834723530681)

# %%
df['CREDIT_LIMIT_LOG'].median()
# Out:
# np.float64(8.006700845440367)

# %%
# Fill up the missing elements with mean of the 'CREDIT_LIMIT’ 
df['CREDIT_LIMIT_LOG'] = df['CREDIT_LIMIT_LOG'].fillna(df['CREDIT_LIMIT_LOG'].mean(), inplace = True)
df['CREDIT_LIMIT_LOG']
# Out:
# 0       6.908755
# 1       8.853808
# 2       8.922792
# 3       8.922792
# 4       7.090910
#           ...
# 8945    6.908755
# 8946    6.908755
# 8947    6.908755
# 8948    6.216606
# 8949    7.090910
# Name: CREDIT_LIMIT_LOG, Length: 8950, dtype: float64

# %%
df.isnull().sum()
# Out:
# CUST_ID                             0
# BALANCE_FREQUENCY                   0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# BALANCE_LOG                         0
# PURCHASES_LOG                       0
# ONEOFF_PURCHASES_LOG                0
# INSTALLMENTS_PURCHASES_LOG          0
# CASH_ADVANCE_LOG                    0
# CREDIT_LIMIT_LOG                    0
# PAYMENTS_LOG                        0
# MINIMUM_PAYMENTS_LOG                0
# dtype: int64

# %%
# Check duplicated entries in the data
print(df.duplicated().sum())
# Out:
# 0

# %%
# Drop Customer ID since it has no meaning here 
df = df.drop(['CUST_ID'], axis = 1)

# %%
df.head(10)
# Out:
#    BALANCE_FREQUENCY  PURCHASES_FREQUENCY  ONEOFF_PURCHASES_FREQUENCY  \
# 0           0.818182             0.166667                    0.000000
# 1           0.909091             0.000000                    0.000000
# 2           1.000000             1.000000                    1.000000
# 3           0.636364             0.083333                    0.083333
# 4           1.000000             0.083333                    0.083333
# 5           1.000000             0.666667                    0.000000
# 6           1.000000             1.000000                    1.000000
# 7           1.000000             1.000000                    0.000000
# 8           1.000000             0.333333                    0.083333
# 9           0.545455             0.166667                    0.166667
#
#    PURCHASES_INSTALLMENTS_FREQUENCY  CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  \
# 0                          0.083333                0.000000                 0
# 1                          0.000000                0.250000                 4
# 2                          0.000000                0.000000                 0
# 3                          0.000000                0.083333                 1
# 4                          0.000000                0.000000                 0
# 5                          0.583333                0.000000                 0
# 6                          1.000000                0.000000                 0
# 7                          1.000000                0.000000                 0
# 8                          0.250000                0.000000                 0
# 9                          0.000000                0.000000                 0
#
#    PURCHASES_TRX  PRC_FULL_PAYMENT  TENURE  BALANCE_LOG  PURCHASES_LOG  \
# 0              2          0.000000      12     3.735304       4.568506
# 1              0          0.222222      12     8.071989       0.000000
# 2             12          0.000000      12     7.822504       6.651791
# 3              1          0.000000      12     7.419183       7.313220
# 4              1          0.000000      12     6.707735       2.833213
# 5              8          0.000000      12     7.501540       7.196147
# 6             64          1.000000      12     6.442955       8.866724
# 7             12          0.000000      12     7.509145       6.080391
# 8              5          0.000000      12     6.923556       6.759824
# 9              3          0.000000      12     5.031914       7.156645
#
#    ONEOFF_PURCHASES_LOG  INSTALLMENTS_PURCHASES_LOG  CASH_ADVANCE_LOG  \
# 0              0.000000                    4.568506          0.000000
# 1              0.000000                    0.000000          8.770896
# 2              6.651791                    0.000000          0.000000
# 3              7.313220                    0.000000          5.331694
# 4              2.833213                    0.000000          0.000000
# 5              0.000000                    7.196147          0.000000
# 6              8.764620                    6.535793          0.000000
# 7              0.000000                    6.080391          0.000000
# 8              6.496005                    5.303305          0.000000
# 9              7.156645                    0.000000          0.000000
#
#    CREDIT_LIMIT_LOG  PAYMENTS_LOG  MINIMUM_PAYMENTS_LOG
# 0          6.908755      5.312231              4.945277
# 1          8.853808      8.319725              6.978531
# 2          8.922792      6.434654              6.442994
# 3          8.922792      0.000000              5.922195
# 4          7.090910      6.521114              5.504483
# 5          7.496097      7.244983              7.786654
# 6          9.510519      8.757047              5.293636
# 7          7.741099      6.522189              6.278585
# 8          8.853808      6.535645              5.746086
# 9          9.305741      7.061138              4.618109

# %%
df.columns
# Out:
# Index(['BALANCE_FREQUENCY', 'PURCHASES_FREQUENCY',
#        'ONEOFF_PURCHASES_FREQUENCY', 'PURCHASES_INSTALLMENTS_FREQUENCY',
#        'CASH_ADVANCE_FREQUENCY', 'CASH_ADVANCE_TRX', 'PURCHASES_TRX',
#        'PRC_FULL_PAYMENT', 'TENURE', 'BALANCE_LOG', 'PURCHASES_LOG',
#        'ONEOFF_PURCHASES_LOG', 'INSTALLMENTS_PURCHASES_LOG',
#        'CASH_ADVANCE_LOG', 'CREDIT_LIMIT_LOG', 'PAYMENTS_LOG',
#        'MINIMUM_PAYMENTS_LOG'],
#       dtype='str')

# %%
len(df.columns)
# Out:
# 17

# %%
plt.figure(figsize = (10,50))
for i in range(len(df.columns)):
    plt.subplot(17, 1,i+1)
    sns.distplot(df[df.columns[i]], kde_kws = {"color":"b", "lw":3,"label": "KDE"}, hist_kws={"color": "g"})
    plt.title(df.columns[i])

plt.tight_layout()

# %%
df_corr = df.corr()
print(df_corr)
# Out:
#                                   BALANCE_FREQUENCY  PURCHASES_FREQUENCY  \
# BALANCE_FREQUENCY                          1.000000             0.229715
# PURCHASES_FREQUENCY                        0.229715             1.000000
# ONEOFF_PURCHASES_FREQUENCY                 0.202415             0.501343
# PURCHASES_INSTALLMENTS_FREQUENCY           0.176079             0.862934
# CASH_ADVANCE_FREQUENCY                     0.191873            -0.308478
# CASH_ADVANCE_TRX                           0.141555            -0.203478
# PURCHASES_TRX                              0.189626             0.568430
# PRC_FULL_PAYMENT                          -0.095082             0.305802
# TENURE                                     0.119776             0.061506
# BALANCE_LOG                                0.652592            -0.093945
# PURCHASES_LOG                              0.096993             0.781750
# ONEOFF_PURCHASES_LOG                       0.140453             0.373634
# INSTALLMENTS_PURCHASES_LOG                 0.112687             0.794784
# CASH_ADVANCE_LOG                           0.164510            -0.432610
# CREDIT_LIMIT_LOG                           0.095024             0.112630
# PAYMENTS_LOG                               0.322262             0.175997
# MINIMUM_PAYMENTS_LOG                       0.408730            -0.054649
#
#                                   ONEOFF_PURCHASES_FREQUENCY  \
# BALANCE_FREQUENCY                                   0.202415
# PURCHASES_FREQUENCY                                 0.501343
# ONEOFF_PURCHASES_FREQUENCY                          1.000000
# PURCHASES_INSTALLMENTS_FREQUENCY                    0.142329
# CASH_ADVANCE_FREQUENCY                             -0.111716
# CASH_ADVANCE_TRX                                   -0.069088
# PURCHASES_TRX                                       0.544869
# PRC_FULL_PAYMENT                                    0.157531
# TENURE                                              0.082466
# BALANCE_LOG                                         0.146987
# PURCHASES_LOG                                       0.547315
# ONEOFF_PURCHASES_LOG                                0.769934
# INSTALLMENTS_PURCHASES_LOG                          0.189930
# CASH_ADVANCE_LOG                                   -0.181973
# CREDIT_LIMIT_LOG                                    0.288051
# PAYMENTS_LOG                                        0.271411
# MINIMUM_PAYMENTS_LOG                                0.034932
#
#                                   PURCHASES_INSTALLMENTS_FREQUENCY  \
# BALANCE_FREQUENCY                                         0.176079
# PURCHASES_FREQUENCY                                       0.862934
# ONEOFF_PURCHASES_FREQUENCY                                0.142329
# PURCHASES_INSTALLMENTS_FREQUENCY                          1.000000
# CASH_ADVANCE_FREQUENCY                                   -0.262958
# CASH_ADVANCE_TRX                                         -0.169207
# PURCHASES_TRX                                             0.529975
# PRC_FULL_PAYMENT                                          0.250087
# TENURE                                                    0.073275
# BALANCE_LOG                                              -0.107077
# PURCHASES_LOG                                             0.592411
# ONEOFF_PURCHASES_LOG                                      0.092781
# INSTALLMENTS_PURCHASES_LOG                                0.878672
# CASH_ADVANCE_LOG                                         -0.356494
# CREDIT_LIMIT_LOG                                          0.052559
# PAYMENTS_LOG                                              0.132684
# MINIMUM_PAYMENTS_LOG                                     -0.033779
#
#                                   CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  \
# BALANCE_FREQUENCY                               0.191873          0.141555
# PURCHASES_FREQUENCY                            -0.308478         -0.203478
# ONEOFF_PURCHASES_FREQUENCY                     -0.111716         -0.069088
# PURCHASES_INSTALLMENTS_FREQUENCY               -0.262958         -0.169207
# CASH_ADVANCE_FREQUENCY                          1.000000          0.799561
# CASH_ADVANCE_TRX                                0.799561          1.000000
# PURCHASES_TRX                                  -0.131168         -0.066157
# PRC_FULL_PAYMENT                               -0.249773         -0.169784
# TENURE                                         -0.133372         -0.043421
# BALANCE_LOG                                     0.451885          0.352288
# PURCHASES_LOG                                  -0.349000         -0.223205
# ONEOFF_PURCHASES_LOG                           -0.116687         -0.063430
# INSTALLMENTS_PURCHASES_LOG                     -0.288378         -0.179072
# CASH_ADVANCE_LOG                                0.770260          0.586590
# CREDIT_LIMIT_LOG                                0.139850          0.157539
# PAYMENTS_LOG                                    0.193640          0.206498
# MINIMUM_PAYMENTS_LOG                            0.359188          0.316654
#
#                                   PURCHASES_TRX  PRC_FULL_PAYMENT    TENURE  \
# BALANCE_FREQUENCY                      0.189626         -0.095082  0.119776
# PURCHASES_FREQUENCY                    0.568430          0.305802  0.061506
# ONEOFF_PURCHASES_FREQUENCY             0.544869          0.157531  0.082466
# PURCHASES_INSTALLMENTS_FREQUENCY       0.529975          0.250087  0.073275
# CASH_ADVANCE_FREQUENCY                -0.131168         -0.249773 -0.133372
# CASH_ADVANCE_TRX                      -0.066157         -0.169784 -0.043421
# PURCHASES_TRX                          1.000000          0.162066  0.121874
# PRC_FULL_PAYMENT                       0.162066          1.000000 -0.016486
# TENURE                                 0.121874         -0.016486  1.000000
# BALANCE_LOG                            0.146314         -0.408913  0.073873
# PURCHASES_LOG                          0.523937          0.251738  0.106368
# ONEOFF_PURCHASES_LOG                   0.443533          0.043285  0.091953
# INSTALLMENTS_PURCHASES_LOG             0.515391          0.274441  0.099394
# CASH_ADVANCE_LOG                      -0.186309         -0.322740 -0.100459
# CREDIT_LIMIT_LOG                       0.251265          0.047327  0.174808
# PAYMENTS_LOG                           0.303368          0.137520  0.210434
# MINIMUM_PAYMENTS_LOG                   0.125918         -0.358367  0.149462
#
#                                   BALANCE_LOG  PURCHASES_LOG  \
# BALANCE_FREQUENCY                    0.652592       0.096993
# PURCHASES_FREQUENCY                 -0.093945       0.781750
# ONEOFF_PURCHASES_FREQUENCY           0.146987       0.547315
# PURCHASES_INSTALLMENTS_FREQUENCY    -0.107077       0.592411
# CASH_ADVANCE_FREQUENCY               0.451885      -0.349000
# CASH_ADVANCE_TRX                     0.352288      -0.223205
# PURCHASES_TRX                        0.146314       0.523937
# PRC_FULL_PAYMENT                    -0.408913       0.251738
# TENURE                               0.073873       0.106368
# BALANCE_LOG                          1.000000      -0.074977
# PURCHASES_LOG                       -0.074977       1.000000
# ONEOFF_PURCHASES_LOG                 0.180434       0.683510
# INSTALLMENTS_PURCHASES_LOG          -0.110924       0.685390
# CASH_ADVANCE_LOG                     0.521648      -0.496556
# CREDIT_LIMIT_LOG                     0.299803       0.187673
# PAYMENTS_LOG                         0.429075       0.206779
# MINIMUM_PAYMENTS_LOG                 0.755576      -0.052338
#
#                                   ONEOFF_PURCHASES_LOG  \
# BALANCE_FREQUENCY                             0.140453
# PURCHASES_FREQUENCY                           0.373634
# ONEOFF_PURCHASES_FREQUENCY                    0.769934
# PURCHASES_INSTALLMENTS_FREQUENCY              0.092781
# CASH_ADVANCE_FREQUENCY                       -0.116687
# CASH_ADVANCE_TRX                             -0.063430
# PURCHASES_TRX                                 0.443533
# PRC_FULL_PAYMENT                              0.043285
# TENURE                                        0.091953
# BALANCE_LOG                                   0.180434
# PURCHASES_LOG                                 0.683510
# ONEOFF_PURCHASES_LOG                          1.000000
# INSTALLMENTS_PURCHASES_LOG                    0.161434
# CASH_ADVANCE_LOG                             -0.190146
# CREDIT_LIMIT_LOG                              0.284840
# PAYMENTS_LOG                                  0.267027
# MINIMUM_PAYMENTS_LOG                          0.057508
#
#                                   INSTALLMENTS_PURCHASES_LOG  \
# BALANCE_FREQUENCY                                   0.112687
# PURCHASES_FREQUENCY                                 0.794784
# ONEOFF_PURCHASES_FREQUENCY                          0.189930
# PURCHASES_INSTALLMENTS_FREQUENCY                    0.878672
# CASH_ADVANCE_FREQUENCY                             -0.288378
# CASH_ADVANCE_TRX                                   -0.179072
# PURCHASES_TRX                                       0.515391
# PRC_FULL_PAYMENT                                    0.274441
# TENURE                                              0.099394
# BALANCE_LOG                                        -0.110924
# PURCHASES_LOG                                       0.685390
# ONEOFF_PURCHASES_LOG                                0.161434
# INSTALLMENTS_PURCHASES_LOG                          1.000000
# CASH_ADVANCE_LOG                                   -0.394318
# CREDIT_LIMIT_LOG                                    0.106564
# PAYMENTS_LOG                                        0.165432
# MINIMUM_PAYMENTS_LOG                               -0.040019
#
#                                   CASH_ADVANCE_LOG  CREDIT_LIMIT_LOG  \
# BALANCE_FREQUENCY                         0.164510          0.095024
# PURCHASES_FREQUENCY                      -0.432610          0.112630
# ONEOFF_PURCHASES_FREQUENCY               -0.181973          0.288051
# PURCHASES_INSTALLMENTS_FREQUENCY         -0.356494          0.052559
# CASH_ADVANCE_FREQUENCY                    0.770260          0.139850
# CASH_ADVANCE_TRX                          0.586590          0.157539
# PURCHASES_TRX                            -0.186309          0.251265
# PRC_FULL_PAYMENT                         -0.322740          0.047327
# TENURE                                   -0.100459          0.174808
# BALANCE_LOG                               0.521648          0.299803
# PURCHASES_LOG                            -0.496556          0.187673
# ONEOFF_PURCHASES_LOG                     -0.190146          0.284840
# INSTALLMENTS_PURCHASES_LOG               -0.394318          0.106564
# CASH_ADVANCE_LOG                          1.000000          0.119434
# CREDIT_LIMIT_LOG                          0.119434          1.000000
# PAYMENTS_LOG                              0.182519          0.343564
# MINIMUM_PAYMENTS_LOG                      0.406244          0.253932
#
#                                   PAYMENTS_LOG  MINIMUM_PAYMENTS_LOG
# BALANCE_FREQUENCY                     0.322262              0.408730
# PURCHASES_FREQUENCY                   0.175997             -0.054649
# ONEOFF_PURCHASES_FREQUENCY            0.271411              0.034932
# PURCHASES_INSTALLMENTS_FREQUENCY      0.132684             -0.033779
# CASH_ADVANCE_FREQUENCY                0.193640              0.359188
# CASH_ADVANCE_TRX                      0.206498              0.316654
# PURCHASES_TRX                         0.303368              0.125918
# PRC_FULL_PAYMENT                      0.137520             -0.358367
# TENURE                                0.210434              0.149462
# BALANCE_LOG                           0.429075              0.755576
# PURCHASES_LOG                         0.206779             -0.052338
# ONEOFF_PURCHASES_LOG                  0.267027              0.057508
# INSTALLMENTS_PURCHASES_LOG            0.165432             -0.040019
# CASH_ADVANCE_LOG                      0.182519              0.406244
# CREDIT_LIMIT_LOG                      0.343564              0.253932
# PAYMENTS_LOG                          1.000000              0.260271
# MINIMUM_PAYMENTS_LOG                  0.260271              1.000000

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df_corr, annot = True) 
plt.show()

# %%
df
# Out:
#       BALANCE_FREQUENCY  PURCHASES_FREQUENCY  ONEOFF_PURCHASES_FREQUENCY  \
# 0              0.818182             0.166667                    0.000000
# 1              0.909091             0.000000                    0.000000
# 2              1.000000             1.000000                    1.000000
# 3              0.636364             0.083333                    0.083333
# 4              1.000000             0.083333                    0.083333
# ...                 ...                  ...                         ...
# 8945           1.000000             1.000000                    0.000000
# 8946           1.000000             1.000000                    0.000000
# 8947           0.833333             0.833333                    0.000000
# 8948           0.833333             0.000000                    0.000000
# 8949           0.666667             0.666667                    0.666667
#
#       PURCHASES_INSTALLMENTS_FREQUENCY  CASH_ADVANCE_FREQUENCY  \
# 0                             0.083333                0.000000
# 1                             0.000000                0.250000
# 2                             0.000000                0.000000
# 3                             0.000000                0.083333
# 4                             0.000000                0.000000
# ...                                ...                     ...
# 8945                          0.833333                0.000000
# 8946                          0.833333                0.000000
# 8947                          0.666667                0.000000
# 8948                          0.000000                0.166667
# 8949                          0.000000                0.333333
#
#       CASH_ADVANCE_TRX  PURCHASES_TRX  PRC_FULL_PAYMENT  TENURE  BALANCE_LOG  \
# 0                    0              2          0.000000      12     3.735304
# 1                    4              0          0.222222      12     8.071989
# 2                    0             12          0.000000      12     7.822504
# 3                    1              1          0.000000      12     7.419183
# 4                    0              1          0.000000      12     6.707735
# ...                ...            ...               ...     ...          ...
# 8945                 0              6          0.500000       6     3.384170
# 8946                 0              6          0.000000       6     3.004851
# 8947                 0              5          0.250000       6     3.194529
# 8948                 2              0          0.250000       6     2.671218
# 8949                 2             23          0.000000       6     5.923475
#
#       PURCHASES_LOG  ONEOFF_PURCHASES_LOG  INSTALLMENTS_PURCHASES_LOG  \
# 0          4.568506              0.000000                    4.568506
# 1          0.000000              0.000000                    0.000000
# 2          6.651791              6.651791                    0.000000
# 3          7.313220              7.313220                    0.000000
# 4          2.833213              2.833213                    0.000000
# ...             ...                   ...                         ...
# 8945       5.677165              0.000000                    5.677165
# 8946       5.707110              0.000000                    5.707110
# 8947       4.979489              0.000000                    4.979489
# 8948       0.000000              0.000000                    0.000000
# 8949       6.997824              6.997824                    0.000000
#
#       CASH_ADVANCE_LOG  CREDIT_LIMIT_LOG  PAYMENTS_LOG  MINIMUM_PAYMENTS_LOG
# 0             0.000000          6.908755      5.312231              4.945277
# 1             8.770896          8.853808      8.319725              6.978531
# 2             0.000000          8.922792      6.434654              6.442994
# 3             5.331694          8.922792      0.000000              5.922195
# 4             0.000000          7.090910      6.521114              5.504483
# ...                ...               ...           ...                   ...
# 8945          0.000000          6.908755      5.788719              3.909748
# 8946          0.000000          6.908755      5.623517              5.922195
# 8947          0.000000          6.908755      4.410016              4.423869
# 8948          3.625907          6.216606      3.980615              4.038755
# 8949          4.852343          7.090910      4.161464              4.491878
#
# [8950 rows x 17 columns]

# %%
# Apply Feature Scaling .
scaler = StandardScaler()
df_standarized = scaler.fit_transform(df)

# %%
df_standarized.shape
# Out:
# (8950, 17)

# %%
display(pd.DataFrame(df_standarized))
# Out:
#             0         1         2         3         4         5         6   \
# 0    -0.249434 -0.806490 -0.678661 -0.707313 -0.675349 -0.476070 -0.511333
# 1     0.134325 -1.221758 -0.678661 -0.916995  0.573963  0.110074 -0.591796
# 2     0.518084  1.269843  2.673451 -0.916995 -0.675349 -0.476070 -0.109020
# 3    -1.016953 -1.014125 -0.399319 -0.916995 -0.258913 -0.329534 -0.551565
# 4     0.518084 -1.014125 -0.399319 -0.916995 -0.675349 -0.476070 -0.551565
# ...        ...       ...       ...       ...       ...       ...       ...
# 8945  0.518084  1.269843 -0.678661  1.179833 -0.675349 -0.476070 -0.350408
# 8946  0.518084  1.269843 -0.678661  1.179833 -0.675349 -0.476070 -0.350408
# 8947 -0.185477  0.854576 -0.678661  0.760469 -0.675349 -0.476070 -0.390639
# 8948 -0.185477 -1.221758 -0.678661 -0.916995  0.157527 -0.182998 -0.591796
# 8949 -0.889033  0.439310  1.556082 -0.916995  0.990398 -0.182998  0.333524
#
#             7         8         9         10        11        12        13  \
# 0    -0.525551  0.360680 -1.205218 -0.113532 -0.987090  0.394480 -0.930733
# 1     0.234227  0.360680  0.948918 -1.679855 -0.987090 -1.087454  1.528788
# 2    -0.525551  0.360680  0.824993  0.600727  1.062022 -1.087454 -0.930733
# 3    -0.525551  0.360680  0.624653  0.827499  1.265778 -1.087454  0.564372
# 4    -0.525551  0.360680  0.271260 -0.708481 -0.114307 -1.087454 -0.930733
# ...        ...       ...       ...       ...       ...       ...       ...
# 8945  1.183951 -4.122768 -1.379634  0.266574 -0.987090  0.754107 -0.930733
# 8946 -0.525551 -4.122768 -1.568051  0.276841 -0.987090  0.763821 -0.930733
# 8947  0.329200 -4.122768 -1.473834  0.027374 -0.987090  0.527794 -0.930733
# 8948  0.329200 -4.122768 -1.733775 -1.679855 -0.987090 -1.087454  0.086038
# 8949 -0.525551 -4.122768 -0.118301  0.719365  1.168619 -1.087454  0.429953
#
#             14        15            16
# 0    -1.447175 -0.824484 -8.353848e-01
# 1     0.926049  1.065033  9.032966e-01
# 2     1.010218 -0.119300  4.453465e-01
# 3     1.010218 -4.161996 -7.595016e-16
# 4    -1.224922 -0.064979 -3.571956e-01
# ...        ...       ...           ...
# 8945 -1.447175 -0.525121 -1.720890e+00
# 8946 -1.447175 -0.628912 -7.595016e-16
# 8947 -1.447175 -1.391318 -1.281253e+00
# 8948 -2.291689 -1.661097 -1.610573e+00
# 8949 -1.224922 -1.547475 -1.223097e+00
#
# [8950 rows x 17 columns]

# %%
# Identify the Optimum number of clusters ( Elbow method)
wcss = []
for k in range(1, 20):      
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(df_standarized)
    wcss.append(kmeans.inertia_)
# Out:
#   File "C:\Users\xnovaq.16\Documents\myenv\venv\Lib\site-packages\joblib\externals\loky\backend\context.py", line 247, in _count_physical_cores
#     cpu_count_physical = _count_physical_cores_win32()
#   File "C:\Users\xnovaq.16\Documents\myenv\venv\Lib\site-packages\joblib\externals\loky\backend\context.py", line 299, in _count_physical_cores_win32
#     cpu_info = subprocess.run(
#         "wmic CPU Get NumberOfCores /Format:csv".split(),
#         capture_output=True,
#         text=True,
#     )
#   File "C:\Users\xnovaq.16\AppData\Local\Python\pythoncore-3.14-64\Lib\subprocess.py", line 554, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\xnovaq.16\AppData\Local\Python\pythoncore-3.14-64\Lib\subprocess.py", line 1038, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#     ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                         pass_fds, cwd, env,
#                         ^^^^^^^^^^^^^^^^^^^
#     ...<5 lines>...
#                         gid, gids, uid, umask,
#                         ^^^^^^^^^^^^^^^^^^^^^^
#                         start_new_session, process_group)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\xnovaq.16\AppData\Local\Python\pythoncore-3.14-64\Lib\subprocess.py", line 1552, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#                              # no special security
#                              ^^^^^^^^^^^^^^^^^^^^^
#     ...<4 lines>...
#                              cwd,
#                              ^^^^
#                              startupinfo)
#                              ^^^^^^^^^^^^

# %%
plt.plot(range(1,20), wcss, marker='o')
plt.xlabel("Clusters")
plt.ylabel("Scores")
plt.title("Finding the right number of clusters")
plt.show()

# %%
# Create the K Means Clustering Algorithm
kmeans = KMeans(6)
kmeans.fit(df_standarized)
y_kmeans = kmeans.labels_

# %%
kmeans.cluster_centers_.shape
# Out:
# (6, 17)

# %%
df['Cluster'] = kmeans.labels_

# %%
cluster_profile = df.groupby('Cluster').mean()
display(cluster_profile)
# Out:
#          BALANCE_FREQUENCY  PURCHASES_FREQUENCY  ONEOFF_PURCHASES_FREQUENCY  \
# Cluster
# 0                 0.935063             0.834729                    0.041913
# 1                 0.932357             0.017078                    0.008610
# 2                 0.348077             0.274485                    0.066167
# 3                 0.982974             0.948399                    0.667193
# 4                 0.943720             0.401542                    0.328991
# 5                 0.975724             0.608568                    0.254637
#
#          PURCHASES_INSTALLMENTS_FREQUENCY  CASH_ADVANCE_FREQUENCY  \
# Cluster
# 0                                0.787532                0.021500
# 1                                0.007215                0.276613
# 2                                0.196705                0.024398
# 3                                0.744179                0.038895
# 4                                0.088791                0.052813
# 5                                0.439342                0.477670
#
#          CASH_ADVANCE_TRX  PURCHASES_TRX  PRC_FULL_PAYMENT     TENURE  \
# Cluster
# 0                0.378741      15.069143          0.294834  11.458204
# 1                5.932638       0.224383          0.030991  11.386148
# 2                0.463346       3.995301          0.213658  11.253759
# 3                0.731355      52.584475          0.277177  11.904871
# 4                0.911246       8.122796          0.071238  11.635866
# 5               14.624291      17.329171          0.034394  11.480136
#
#          BALANCE_LOG  PURCHASES_LOG  ONEOFF_PURCHASES_LOG  \
# Cluster
# 0           5.177963       6.210402              1.254065
# 1           7.301729       0.516422              0.350439
# 2           2.671506       4.400576              2.168011
# 3           6.864226       7.936468              7.260667
# 4           6.546748       6.128276              5.798160
# 5           8.045678       6.283449              4.680926
#
#          INSTALLMENTS_PURCHASES_LOG  CASH_ADVANCE_LOG  CREDIT_LIMIT_LOG  \
# Cluster
# 0                          6.106971          0.880085          7.730085
# 1                          0.171095          6.908832          8.008959
# 2                          2.645309          1.179649          7.868487
# 3                          6.462989          1.490449          8.708204
# 4                          1.638581          1.968838          8.003722
# 5                          4.319627          7.927424          8.631336
#
#          PAYMENTS_LOG  MINIMUM_PAYMENTS_LOG
# Cluster
# 0            6.314039              5.540867
# 1            6.689624              6.332253
# 2            5.067195              4.662518
# 3            7.756462              6.087312
# 4            6.457427              5.913845
# 5            7.656463              7.070528

# %%
cluster_names = {
    0: "Low spenders, low balance",
    1: "High cash advance users",
    2: "Installment buyers",
    3: "Big one-off purchasers",
    4: "Inactive / dormant users",
    5: "Full payment, high credit"
}

# %%
df['Cluster_Name'] = df['Cluster'].map(cluster_names)
df[['Cluster', 'Cluster_Name']].value_counts().sort_index()
# Out:
# Cluster  Cluster_Name
# 0        Low spenders, low balance    1938
# 1        High cash advance users      2108
# 2        Installment buyers           1064
# 3        Big one-off purchasers       1314
# 4        Inactive / dormant users     1645
# 5        Full payment, high credit     881
# Name: count, dtype: int64

# %%
df['Cluster'].value_counts().plot(kind='bar', color='purple')
plt.title("Number of customers per cluster")
plt.xlabel("Cluster")
plt.ylabel("Count")
plt.savefig("Number of customers per cluster.jpg")
plt.show()

# %%
y_kmeans = kmeans.fit_predict(df_standarized)
display(y_kmeans)
# Out:
# array([5, 2, 4, ..., 3, 5, 4], shape=(8950,), dtype=int32)

# %%
# Silhouette Score: 0.204
# Score is low but acceptable for real-world high-dimensional customer data.
# Customer segments naturally overlap in behavior, making clean separation difficult.
from sklearn.metrics import silhouette_score
score = silhouette_score(df_standarized,y_kmeans)
print("Silhouette Score: ", score)
# Out:
# Silhouette Score:  0.20428350581578145

# %%
from sklearn.cluster import DBSCAN

dbscan = DBSCAN(eps=0.5, min_samples=5)
df['DBSCAN_Cluster'] = dbscan.fit_predict(df_standarized)

# -1 means outliers in DBSCAN
print("Number of clusters found:", len(set(df['DBSCAN_Cluster'])) - 1)
print("Outliers found:", (df['DBSCAN_Cluster'] == -1).sum())
# Out:
# Number of clusters found: 27
# Outliers found: 8047

# %%
from sklearn.cluster import AgglomerativeClustering

agg = AgglomerativeClustering(n_clusters=6)
df['Agg_Cluster'] = agg.fit_predict(df_standarized)

# %%
from sklearn.metrics import silhouette_score

kmeans_score = silhouette_score(df_standarized, df['Cluster'])
agg_score = silhouette_score(df_standarized, df['Agg_Cluster'])

# DBSCAN only if it found valid clusters (exclude outliers)
dbscan_mask = df['DBSCAN_Cluster'] != -1
dbscan_score = silhouette_score(df_standarized[dbscan_mask], df['DBSCAN_Cluster'][dbscan_mask])

print(f"K-Means Silhouette Score:      {kmeans_score:.4f}")
print(f"Agglomerative Silhouette Score: {agg_score:.4f}")
print(f"DBSCAN Silhouette Score:        {dbscan_score:.4f}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[51], line 4
#       1 from sklearn.metrics import silhouette_score
#       3 kmeans_score = silhouette_score(df_standarized, df['Cluster'])
# ----> 4 agg_score = silhouette_score(df_standarized, df['Agg_Cluster'])
#       6 # DBSCAN only if it found valid clusters (exclude outliers)
#       7 dbscan_mask = df['DBSCAN_Cluster'] != -1
#
# File ~\Documents\myenv\venv\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~\Documents\myenv\venv\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py:146, in silhouette_score(X, labels, metric, sample_size, random_state, **kwds)
#     144     else:
#     145         X, labels = X[indices], labels[indices]
# --> 146 return float(np.mean(silhouette_samples(X, labels, metric=metric, **kwds)))
#
# File ~\Documents\myenv\venv\Lib\site-packages\sklearn\utils\_param_validation.py:191, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     189 global_skip_validation = get_config()["skip_parameter_validation"]
#     190 if global_skip_validation:
# --> 191     return func(*args, **kwargs)
#     193 func_sig = signature(func)
#     195 # Map *args/**kwargs to the function signature
#
# File ~\Documents\myenv\venv\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py:310, in silhouette_samples(X, labels, metric, **kwds)
#     306 kwds["metric"] = metric
#     307 reduce_func = functools.partial(
#     308     _silhouette_reduce, labels=labels, label_freqs=label_freqs
#     309 )
# --> 310 results = zip(*pairwise_distances_chunked(X, reduce_func=reduce_func, **kwds))
#     311 intra_clust_dists, inter_clust_dists = results
#     312 intra_clust_dists = np.concatenate(intra_clust_dists)
#
# File ~\Documents\myenv\venv\Lib\site-packages\sklearn\metrics\pairwise.py:2264, in pairwise_distances_chunked(X, Y, reduce_func, metric, n_jobs, working_memory, **kwds)
#    2262 else:
#    2263     X_chunk = X[sl]
# -> 2264 D_chunk = pairwise_distances(X_chunk, Y, metric=metric, n_jobs=n_jobs, **kwds)
#    2265 if (X is Y or Y is None) and PAIRWISE_DISTANCE_FUNCTIONS.get(
#    2266     metric, None
#    2267 ) is euclidean_distances:
#    2268     # zeroing diagonal, taking care of aliases of "euclidean",
#    2269     # i.e. "l2"
#    2270     D_chunk.flat[sl.start :: _num_samples(X) + 1] = 0
#
# File ~\Documents\myenv\venv\Lib\site-packages\sklearn\utils\_param_validation.py:191, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     189 global_skip_validation = get_config()["skip_parameter_validation"]
#     190 if global_skip_validation:
# --> 191     return func(*args, **kwargs)
#     193 func_sig = signature(func)
#     195 # Map *args/**kwargs to the function signature
#
# File ~\Documents\myenv\venv\Lib\site-packages\sklearn\metrics\pairwise.py:2473, in pairwise_distances(X, Y, metric, n_jobs, ensure_all_finite, **kwds)
#    2470         return distance.squareform(distance.pdist(X, metric=metric, **kwds))
#    2471     func = partial(distance.cdist, metric=metric, **kwds)
# -> 2473 return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#
# File ~\Documents\myenv\venv\Lib\site-packages\sklearn\metrics\pairwise.py:1969, in _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1966     Y = X
#    1968 if effective_n_jobs(n_jobs) == 1:
# -> 1969     return func(X, Y, **kwds)
#    1971 # enforce a threading backend to prevent data communication overhead
#    1972 fd = delayed(_transposed_dist_wrapper)
#
# File ~\Documents\myenv\venv\Lib\site-packages\sklearn\utils\_param_validation.py:191, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     189 global_skip_validation = get_config()["skip_parameter_validation"]
#     190 if global_skip_validation:
# --> 191     return func(*args, **kwargs)
#     193 func_sig = signature(func)
#     195 # Map *args/**kwargs to the function signature
#
# File ~\Documents\myenv\venv\Lib\site-packages\sklearn\metrics\pairwise.py:371, in euclidean_distances(X, Y, Y_norm_squared, squared, X_norm_squared)
#     365     if Y_norm_squared.shape != (1, Y.shape[0]):
#     366         raise ValueError(
#     367             f"Incompatible dimensions for Y of shape {Y.shape} and "
#     368             f"Y_norm_squared of shape {original_shape}."
#     369         )
# --> 371 return _euclidean_distances(X, Y, X_norm_squared, Y_norm_squared, squared)
#
# File ~\Documents\myenv\venv\Lib\site-packages\sklearn\metrics\pairwise.py:407, in _euclidean_distances(X, Y, X_norm_squared, Y_norm_squared, squared)
#     404     distances = _euclidean_distances_upcast(X, XX, Y, YY)
#     405 else:
#     406     # if dtype is already float64, no need to chunk and upcast
# --> 407     distances = -2 * safe_sparse_dot(X, Y.T, dense_output=True)
#     408     distances += XX
#     409     distances += YY
#
# File ~\Documents\myenv\venv\Lib\site-packages\sklearn\utils\extmath.py:230, in safe_sparse_dot(a, b, dense_output)
#     226 else:
#     227     ret = a @ b
#     229 if (
# --> 230     sparse.issparse(a)
#     231     and sparse.issparse(b)
#     232     and dense_output
#     233     and hasattr(ret, "toarray")
#     234 ):
#     235     return ret.toarray()
#     236 return ret
#
# File ~\Documents\myenv\venv\Lib\site-packages\scipy\_lib\_sparse.py:10, in issparse(x)
#       6 class SparseABC(ABC):
#       7     pass
# ---> 10 def issparse(x):
#      11     """Is `x` of a sparse array or sparse matrix type?
#      12
#      13     Parameters
#    (...)     39     False
#      40     """
#      41     return isinstance(x, SparseABC)
#
# KeyboardInterrupt:

# %%
scores = {
    'K-Means': kmeans_score,
    'Agglomerative': agg_score,
    'DBSCAN': dbscan_score
}

plt.bar(scores.keys(), scores.values(), color=['green', 'blue', 'purple'])
plt.title("Silhouette Score Comparison")
plt.ylabel("Score")
plt.savefig("Silhouette Score Comparison.jpg")
plt.show()

# %%
# Apply PCA in the Data Set and create clusters 
pca = PCA(n_components=2)
principal_component = pca.fit_transform(df_standarized)
display(principal_component)

# %%
# PCA was applied after clustering purely for visualization. 
# If I had applied PCA before clustering, I would have lost important information from the original 17 features, 
# which could have affected the quality of clusters.
print("Explained variance by each component:", pca.explained_variance_ratio_)
print("Total variance retained:", sum(pca.explained_variance_ratio_))

# %%
plt.scatter(principal_component[:, 0], principal_component[:, 1], c=df['Cluster'])
plt.title("PCA - Customer Segments")
plt.savefig("PCA - Customer Segments.jpg")
plt.show()

# %%
pca_df = pd.DataFrame(data = principal_component, columns =['pca1','pca2'])
pca_df.head()

# %%
pca_df = pd.concat([pca_df,pd.DataFrame({'cluster':y_kmeans})], axis = 1)
display(pca_df)

# %%
pca_df.value_counts(pca_df.cluster)

# %%
plt.figure(figsize=(20,10))
ax = sns.scatterplot(x="pca1", y="pca2", hue = "cluster", data = pca_df, palette =['red','green','blue','pink','yellow','gray','purple', 'black'])
plt.title("PCA scatter plot showing the 6 clusters")
plt.savefig("PCA scatter plot showing the 6 clusters.jpg")
plt.show()

# %%
import pickle

# Save all 3 files
pickle.dump(kmeans, open('kmeans_model.pkl', 'wb'))
pickle.dump(scaler, open('scaler.pkl', 'wb'))

print("Saved at:", os.getcwd())

print("Models saved successfully!")

# %%
import os
print(os.getcwd())

# Also check if pickle files actually exist
import os.path
print(os.path.exists('kmeans_model.pkl'))
print(os.path.exists('scaler.pkl'))
